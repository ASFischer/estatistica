# %%
import numpy as np
from scipy  import stats

# %%
jogadores = [40000, 18000, 150000, 50000, 30000, 100000, 80000]

np.mean(jogadores)
# Out:
# np.float64(66857.14285714286)

# %%
np.median(jogadores)
# Out:
# np.float64(50000.0)

# %%
quartis = np.quantile(jogadores, [0.25, 0.50, 0.75, 1])
quartis
# Out:
# array([ 35000.,  50000.,  90000., 150000.])

# %%
np.std(jogadores)
# Out:
# np.float64(42986.471531097755)

# %%
stats.describe(jogadores)
# Out:
# DescribeResult(nobs=np.int64(7), minmax=(np.int64(18000), np.int64(150000)), mean=np.float64(66857.14285714286), variance=np.float64(2155809523.809524), skewness=np.float64(0.7599791208266361), kurtosis=np.float64(-0.6082421725565053))
