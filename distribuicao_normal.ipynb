# %%
from scipy.stats import norm

# %%
#Conjunto de objetos com media 8 e desvio padrao 2
#Qual a probabilidade de tirar um com peso menor que 6?

norm.cdf(6, 8, 2)
# Out:
# np.float64(0.15865525393145707)

# %%
#Agora de um peso maior que 6 kilos

#norm.sf(6, 8, 2)
1- norm.cdf(6, 8, 2)
# Out:
# np.float64(0.8413447460685429)

# %%
norm.cdf(6, 8, 2) + norm.sf(10, 8 ,2)
# Out:
# np.float64(0.31731050786291415)

# %%
# objeto com peso menor que 10 e maior que 8

norm.cdf(10, 8, 2) - norm.sf ( 8, 8, 2)
# Out:
# np.float64(0.3413447460685429)
